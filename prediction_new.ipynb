# %% [markdown]
# # New model for prediction

# %% [markdown]
# # Chapter 33

# %%
import pandas as pd
new_data={
    
    "Hours": [ 2, 3, 4, 5, 6, 7, 8], 

    "Score": [ 42, 51, 60, 68, 77, 85, 90]
}
df=pd.DataFrame(new_data)
print(df)
# Out:
#    Hours  Score
# 0      2     42
# 1      3     51
# 2      4     60
# 3      5     68
# 4      6     77
# 5      7     85
# 6      8     90

# %%
x_new = df[["Hours"]]
y_new = df["Score"]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x_new,
    y_new,
    test_size=0.2,
    random_state=42
   
)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train) 
print("Model Coefficient (Slope):", model.coef_[0])
print("Model Intercept:", model.intercept_)
# Out:
# Model Coefficient (Slope): 7.699999999999998
# Model Intercept: 29.80000000000001

# %%
y_pred = model.predict(x_test)
pred_data = {'y_prediction': y_pred.round(2),
             'y_test': y_test.reset_index(drop=True)}
prediction_table = pd.DataFrame(pred_data)
prediction_table
# Out:
#    y_prediction  y_test
# 0          45.2      42
# 1          52.9      51

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"MSE  : {mse:.2f}")
print(f"RMSE : {rmse:.2f}")
print(f"R²   : {r2:.3f}")
# Out:
# MSE  : 6.93
# RMSE : 2.63
# R²   : 0.658

# %%
new_input=pd.DataFrame([[1]],columns=['Hours'])
print(model.predict(new_input))
# Out:
# [37.5]
